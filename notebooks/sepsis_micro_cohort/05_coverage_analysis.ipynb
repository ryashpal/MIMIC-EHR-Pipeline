# %% [markdown]
# # Coverage Analysis

# %% [markdown]
# ## Vitals

# %% [markdown]
# ### avg

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/vitals_avg_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_avg_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:33,569 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:33,570 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:33,570 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/vitals_avg_episode_date.csv
# 2023-11-29 21:46:33,570 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:33,570 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:33,570 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:33,571 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:33,571 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/vitals_avg_episode_date.csv
# 2023-11-29 21:46:33,571 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:35,187 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:35,190 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### min

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/vitals_min_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_min_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:36,618 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/vitals_min_episode_date.csv
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/vitals_min_episode_date.csv
# 2023-11-29 21:46:36,619 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:38,114 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:38,116 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### max

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/vitals_max_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_max_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:39,571 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/vitals_max_episode_date.csv
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/vitals_max_episode_date.csv
# 2023-11-29 21:46:39,573 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:41,098 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:41,100 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### first

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/vitals_first_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_first_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:43,236 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/vitals_first_episode_date.csv
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/vitals_first_episode_date.csv
# 2023-11-29 21:46:43,237 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:44,735 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:44,738 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### last

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/vitals_last_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_last_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:46,183 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/vitals_last_episode_date.csv
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/vitals_last_episode_date.csv
# 2023-11-29 21:46:46,184 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:47,736 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:47,739 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ## Labs

# %% [markdown]
# ### avg

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/labs_avg_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_avg_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:49,019 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:49,020 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/labs_avg_episode_date.csv
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/labs_avg_episode_date.csv
# 2023-11-29 21:46:49,021 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:46:54,283 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:46:54,288 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### min

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/labs_min_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_min_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:46:59,081 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - Start!!
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/labs_min_episode_date.csv
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/labs_min_episode_date.csv
# 2023-11-29 21:46:59,082 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:47:04,598 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:47:04,602 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### max

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/labs_max_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_max_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:47:09,045 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:47:09,046 - EHR-QC - INFO - Start!!
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/labs_max_episode_date.csv
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/labs_max_episode_date.csv
# 2023-11-29 21:47:09,047 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:47:14,466 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:47:14,470 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### first

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/labs_first_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_first_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:47:19,457 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - Start!!
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/labs_first_episode_date.csv
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/labs_first_episode_date.csv
# 2023-11-29 21:47:19,458 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:47:24,807 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:47:24,811 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### last

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/extracts/labs_last_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_last_episode_date.csv'''
    )
# Out:
# 2023-11-29 21:47:28,956 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - Start!!
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/extracts/labs_last_episode_date.csv
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.drop: True
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/dropped/labs_last_episode_date.csv
# 2023-11-29 21:47:28,957 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 21:47:34,265 - EHR-QC - INFO - Missingness Report
# 2023-11-29 21:47:34,270 - EHR-QC - INFO -
#
# ...
