# %% [markdown]
# # Final Report Generation

# %% [markdown]
# ## Vitals

# %%
import os


for agg in ['avg', 'min', 'max', 'first', 'last']:
    print('-------------------------------------------------------------------------------------------------------')
    print('Aggregate Function: ', agg)
    print('-------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrqc.plot.ExplorationGraphsPdf'''
        +
        ' ' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '/data/sepsis_micro_cohort/plots/combined/vitals_' + agg + '_episode_date.pdf'
        +
        ''' -c '{'''
        +
        ''' "Respiratory rate" : ["Respiratory rate", "Respiratory rate", "Respiratory rate"],'''
        +
        ''' "Heart rate" : ["Heart rate", "Heart rate", "Heart rate"],'''
        +
        ''' "Body weight" : ["Body weight", "Body weight", "Body weight"],'''
        +
        ''' "Oxygen saturation in Arterial blood by Pulse oximetry" : ["Oxygen saturation in Arterial blood by Pulse oximetry", "Oxygen saturation in Arterial blood by Pulse oximetry", "Oxygen saturation in Arterial blood by Pulse oximetry"],'''
        +
        ''' "Glasgow coma score eye opening" : ["Glasgow coma score eye opening", "Glasgow coma score eye opening", "Glasgow coma score eye opening"],'''
        +
        ''' "Glasgow coma score verbal" : ["Glasgow coma score verbal", "Glasgow coma score verbal", "Glasgow coma score verbal"],'''
        +
        ''' "Glasgow coma score motor" : ["Glasgow coma score motor", "Glasgow coma score motor", "Glasgow coma score motor"],'''
        +
        ''' "Physical mobility Braden scale" : ["Physical mobility Braden scale", "Physical mobility Braden scale", "Physical mobility Braden scale"],'''
        +
        ''' "Nutrition intake pattern Braden scale" : ["Nutrition intake pattern Braden scale", "Nutrition intake pattern Braden scale", "Nutrition intake pattern Braden scale"],'''
        +
        ''' "Sensory perception Braden scale" : ["Sensory perception Braden scale", "Sensory perception Braden scale", "Sensory perception Braden scale"],'''
        +
        ''' "Physical activity Braden scale" : ["Physical activity Braden scale", "Physical activity Braden scale", "Physical activity Braden scale"],'''
        +
        ''' "Moisture exposure Braden scale" : ["Moisture exposure Braden scale", "Moisture exposure Braden scale", "Moisture exposure Braden scale"],'''
        +
        ''' "Friction and shear Braden scale" : ["Friction and shear Braden scale", "Friction and shear Braden scale", "Friction and shear Braden scale"],'''
        +
        ''' "Mean blood pressure" : ["Mean blood pressure", "Mean blood pressure", "Mean blood pressure"],'''
        +
        ''' "Systolic blood pressure" : ["Systolic blood pressure", "Systolic blood pressure", "Systolic blood pressure"],'''
        +
        ''' "Diastolic blood pressure" : ["Diastolic blood pressure", "Diastolic blood pressure", "Diastolic blood pressure"],'''
        +
        ''' "Body temperature" : ["Body temperature", "Body temperature", "Body temperature"]'''
        +
        ''' }' '''
        +
        ''' -sf ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/vitals_''' + agg + '''_episode_date.csv ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/imputed/vitals_''' + agg + '''_episode_date.csv ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/cleaned/vitals_''' + agg + '''_episode_date.csv'''
        +
        ''' -l "Raw" "Imputed" "Cleaned"'''
        )
# Out:
# -------------------------------------------------------------------------------------------------------
# Aggregate Function:  avg
# -------------------------------------------------------------------------------------------------------
# 2023-11-30 10:58:31,047 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-30 10:58:31,048 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/plots/combined/vitals_avg_episode_date.pdf
# ...

# %% [markdown]
# ## Labs

# %%
import os


for agg in ['avg', 'min', 'max', 'first', 'last']:
    print('-------------------------------------------------------------------------------------------------------')
    print('Aggregate Function: ', agg)
    print('-------------------------------------------------------------------------------------------------------')
    os.system(
        'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
        +
        '''.venv/bin/python -m ehrqc.plot.ExplorationGraphsPdf'''
        +
        ' ' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '/data/sepsis_micro_cohort/plots/combined/labs_' + agg + '_episode_date.pdf'
        +
        ''' -c '{'''
        +
        ''' "Leukocytes in Blood by Manual count" : ["Leukocytes in Blood by Manual count", "Leukocytes in Blood by Manual count", "Leukocytes in Blood by Manual count"],'''
        +
        ''' "Hematocrit of Blood by Automated count" : ["Hematocrit of Blood by Automated count", "Hematocrit of Blood by Automated count", "Hematocrit of Blood by Automated count"],'''
        +
        ''' "MCHC by Automated count" : ["MCHC by Automated count", "MCHC by Automated count", "MCHC by Automated count"],'''
        +
        ''' "MCH by Automated count" : ["MCH by Automated count", "MCH by Automated count", "MCH by Automated count"],'''
        +
        ''' "Erythrocyte distribution width by Automated count" : ["Erythrocyte distribution width by Automated count", "Erythrocyte distribution width by Automated count", "Erythrocyte distribution width by Automated count"],'''
        +
        ''' "MCV by Automated count" : ["MCV by Automated count", "MCV by Automated count", "MCV by Automated count"],'''
        +
        ''' "Erythrocytes in Blood by Automated count" : ["Erythrocytes in Blood by Automated count", "Erythrocytes in Blood by Automated count", "Erythrocytes in Blood by Automated count"],'''
        +
        ''' "Platelets in Blood by Automated count" : ["Platelets in Blood by Automated count", "Platelets in Blood by Automated count", "Platelets in Blood by Automated count"],'''
        +
        ''' "Hemoglobin in Blood" : ["Hemoglobin in Blood", "Hemoglobin in Blood", "Hemoglobin in Blood"],'''
        +
        ''' "Urea nitrogen in Serum or Plasma" : ["Urea nitrogen in Serum or Plasma", "Urea nitrogen in Serum or Plasma", "Urea nitrogen in Serum or Plasma"],'''
        +
        ''' "Creatinine in Serum or Plasma" : ["Creatinine in Serum or Plasma", "Creatinine in Serum or Plasma", "Creatinine in Serum or Plasma"],'''
        +
        ''' "Potassium in Serum or Plasma" : ["Potassium in Serum or Plasma", "Potassium in Serum or Plasma", "Potassium in Serum or Plasma"],'''
        +
        ''' "Chloride in Serum or Plasma" : ["Chloride in Serum or Plasma", "Chloride in Serum or Plasma", "Chloride in Serum or Plasma"],'''
        +
        ''' "Bicarbonate in Serum or Plasma" : ["Bicarbonate in Serum or Plasma", "Bicarbonate in Serum or Plasma", "Bicarbonate in Serum or Plasma"],'''
        +
        ''' "Sodium in Serum or Plasma" : ["Sodium in Serum or Plasma", "Sodium in Serum or Plasma", "Sodium in Serum or Plasma"],'''
        +
        ''' "Anion gap 4 in Serum or Plasma" : ["Anion gap 4 in Serum or Plasma", "Anion gap 4 in Serum or Plasma", "Anion gap 4 in Serum or Plasma"],'''
        +
        ''' "Glucose in Serum or Plasma" : ["Glucose in Serum or Plasma", "Glucose in Serum or Plasma", "Glucose in Serum or Plasma"],'''
        +
        ''' "Magnesium in Serum or Plasma" : ["Magnesium in Serum or Plasma", "Magnesium in Serum or Plasma", "Magnesium in Serum or Plasma"],'''
        +
        ''' "Calcium in Serum or Plasma" : ["Calcium in Serum or Plasma", "Calcium in Serum or Plasma", "Calcium in Serum or Plasma"],'''
        +
        ''' "Phosphate in Serum or Plasma" : ["Phosphate in Serum or Plasma", "Phosphate in Serum or Plasma", "Phosphate in Serum or Plasma"],'''
        +
        ''' "Neutrophils in Urine by Automated count" : ["Neutrophils in Urine by Automated count", "Neutrophils in Urine by Automated count", "Neutrophils in Urine by Automated count"],'''
        +
        ''' "Lymphocytes in Blood by Automated count" : ["Lymphocytes in Blood by Automated count", "Lymphocytes in Blood by Automated count", "Lymphocytes in Blood by Automated count"],'''
        +
        ''' "Basophils in Blood by Automated count" : ["Basophils in Blood by Automated count", "Basophils in Blood by Automated count", "Basophils in Blood by Automated count"],'''
        +
        ''' "Eosinophils in Blood by Automated count" : ["Eosinophils in Blood by Automated count", "Eosinophils in Blood by Automated count", "Eosinophils in Blood by Automated count"],'''
        +
        ''' "Monocytes in Blood by Automated count" : ["Monocytes in Blood by Automated count", "Monocytes in Blood by Automated count", "Monocytes in Blood by Automated count"],'''
        +
        ''' "Prothrombin time (PT)" : ["Prothrombin time (PT)", "Prothrombin time (PT)", "Prothrombin time (PT)"],'''
        +
        ''' "INR in Platelet poor plasma by Coagulation assay" : ["INR in Platelet poor plasma by Coagulation assay", "INR in Platelet poor plasma by Coagulation assay", "INR in Platelet poor plasma by Coagulation assay"],'''
        +
        ''' "aPTT in Blood by Coagulation assay" : ["aPTT in Blood by Coagulation assay", "aPTT in Blood by Coagulation assay", "aPTT in Blood by Coagulation assay"],'''
        +
        ''' "Specific gravity of Urine by Test strip" : ["Specific gravity of Urine by Test strip", "Specific gravity of Urine by Test strip", "Specific gravity of Urine by Test strip"],'''
        +
        ''' "pH of Urine by Test strip" : ["pH of Urine by Test strip", "pH of Urine by Test strip", "pH of Urine by Test strip"],'''
        +
        ''' "Bilirubin.total in Serum or Plasma" : ["Bilirubin.total in Serum or Plasma", "Bilirubin.total in Serum or Plasma", "Bilirubin.total in Serum or Plasma"],'''
        +
        ''' "Aspartate aminotransferase in Serum or Plasma" : ["Aspartate aminotransferase in Serum or Plasma", "Aspartate aminotransferase in Serum or Plasma", "Aspartate aminotransferase in Serum or Plasma"],'''
        +
        ''' "Alanine aminotransferase in Serum or Plasma" : ["Alanine aminotransferase in Serum or Plasma", "Alanine aminotransferase in Serum or Plasma", "Alanine aminotransferase in Serum or Plasma"],'''
        +
        ''' "Alkaline phosphatase in Serum or Plasma" : ["Alkaline phosphatase in Serum or Plasma", "Alkaline phosphatase in Serum or Plasma", "Alkaline phosphatase in Serum or Plasma"],'''
        +
        ''' "Albumin in Serum or Plasma" : ["Albumin in Serum or Plasma", "Albumin in Serum or Plasma", "Albumin in Serum or Plasma"]'''
        +
        ''' }' '''
        +
        ''' -sf ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/dropped/labs_''' + agg + '''_episode_date.csv ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_micro_cohort/imputed/labs_''' + agg + '''_episode_date.csv ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/cleaned/labs_''' + agg + '''_episode_date.csv'''
        +
        ''' -l "Raw" "Imputed" "Cleaned"'''
        )
# Out:
# -------------------------------------------------------------------------------------------------------
# Aggregate Function:  avg
# -------------------------------------------------------------------------------------------------------
# 2023-11-30 10:59:18,823 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-30 10:59:18,824 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_micro_cohort/plots/combined/labs_avg_episode_date.pdf
# ...
