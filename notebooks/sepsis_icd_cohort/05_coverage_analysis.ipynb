# %% [markdown]
# # Coverage Analysis

# %% [markdown]
# ## Vitals

# %% [markdown]
# ### avg

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_avg_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/vitals_avg_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:09,148 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/vitals_avg_episode_date.csv
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/vitals_avg_episode_date.csv
# 2023-11-29 01:02:09,149 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:11,743 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:11,746 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### min

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_min_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/vitals_min_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:13,827 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/vitals_min_episode_date.csv
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:13,828 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/vitals_min_episode_date.csv
# 2023-11-29 01:02:13,829 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:16,417 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:16,419 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### max

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_max_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/vitals_max_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:18,499 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/vitals_max_episode_date.csv
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:18,500 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:18,501 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/vitals_max_episode_date.csv
# 2023-11-29 01:02:18,501 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:21,193 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:21,197 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### first

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_first_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/vitals_first_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:23,446 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/vitals_first_episode_date.csv
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/vitals_first_episode_date.csv
# 2023-11-29 01:02:23,447 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:26,016 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:26,019 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### last

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_last_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/vitals_last_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:27,888 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/vitals_last_episode_date.csv
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/vitals_last_episode_date.csv
# 2023-11-29 01:02:27,890 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:30,558 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:30,562 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ## Labs

# %% [markdown]
# ### avg

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/labs_avg_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/labs_avg_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:32,467 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/labs_avg_episode_date.csv
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/labs_avg_episode_date.csv
# 2023-11-29 01:02:32,468 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:39,332 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:39,337 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### min

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/labs_min_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/labs_min_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:44,710 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:44,711 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:44,711 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/labs_min_episode_date.csv
# 2023-11-29 01:02:44,711 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:44,712 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:44,712 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:44,712 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:44,712 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/labs_min_episode_date.csv
# 2023-11-29 01:02:44,712 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:02:51,706 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:02:51,711 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### max

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/labs_max_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/labs_max_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:02:57,028 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - Start!!
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/labs_max_episode_date.csv
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:02:57,029 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/labs_max_episode_date.csv
# 2023-11-29 01:02:57,030 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:03:03,918 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:03:03,923 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### first

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/labs_first_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/labs_first_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:03:09,151 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - Start!!
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/labs_first_episode_date.csv
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/labs_first_episode_date.csv
# 2023-11-29 01:03:09,152 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:03:15,981 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:03:15,985 - EHR-QC - INFO -
#
# ...

# %% [markdown]
# ### last

# %%
import os


os.system(
    'cd ' + os.environ['EHR_QC_PREPROCESS_BASE'] + ';'
    +
    '''.venv/bin/python -m ehrqc.coverage.Coverage ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/labs_last_episode_date.csv 100 -i "person_id" "visit_occurrence_id" -d -p 25 -sp ''' + os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/dropped/labs_last_episode_date.csv'''
    )
# Out:
# 2023-11-29 01:03:21,149 - EHR-QC - INFO - Parsing command line arguments
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - Start!!
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.source_file: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/extracts/labs_last_episode_date.csv
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.chunksize: 100
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.id_columns: ['person_id', 'visit_occurrence_id']
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.drop: True
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.percentage: 25.0
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - args.save_path: /home/yram0006/phd/chapter_2/workspace/MIMIC-EHR-Pipeline/data/sepsis_icd_cohort/dropped/labs_last_episode_date.csv
# 2023-11-29 01:03:21,150 - EHR-QC - INFO - Calculating Missingnes
# 2023-11-29 01:03:28,097 - EHR-QC - INFO - Missingness Report
# 2023-11-29 01:03:28,101 - EHR-QC - INFO -
#
# ...
