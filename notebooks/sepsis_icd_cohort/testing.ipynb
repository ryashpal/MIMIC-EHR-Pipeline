# %%
import os
import pandas as pd


df = pd.read_csv(os.environ['MIMIC_EHR_PIPELINE_BASE'] + '''/data/sepsis_icd_cohort/extracts/vitals_avg_episode_date.csv''')

# %%
df
# Out:
#         person_id  visit_occurrence_id measurement_date  Respiratory rate  \
# 0      2118937575          -2146830423       2153-08-25         16.800000
# 1      2118937575          -2146830423       2153-08-26         14.902439
# 2      2118937575          -2146830423       2153-08-27         18.212121
# 3      2118937575          -2146830423       2153-08-28         23.250000
# 4      2118937575          -2146830423       2153-08-29         22.714286
# ...           ...                  ...              ...               ...
# 68304   949412965           2147302236       2143-10-17         24.323529
# 68305   949412965           2147302236       2143-10-18         23.657895
# 68306   949412965           2147302236       2143-10-19         21.391304
# 68307   949412965           2147302236       2143-10-20         25.260870
# 68308   949412965           2147302236       2143-10-21         25.307692
#
#        Heart rate  Body weight  \
# 0       88.500000        109.8
# ...

# %%
df['Heart rate rhythm'].isna().sum()
# Out:
# 68309
